# %%
import matplotlib.pyplot as plt
import numpy as np
import datetime
import time

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

body = client_35c6879931e14bcf8e5ce89488a9e397.get_object(Bucket='propertyindex-donotdelete-pr-rczpymgfxagsf7',Key='centaindex.csv')['Body']
centa_df = pd.read_csv(body)

# %%
centa_df['Date'] = centa_df['日期'].str.split(' - ').str[0]
centa_df['Date'] = pd.to_datetime(centa_df['Date'], format="%Y-%m-%d")

# %%
centa_df = centa_df.sort_values(by=["Date"], ascending=["False"]).reset_index(drop=True)
centa_df["percentage"] = centa_df.中原城市領先指數/centa_df.中原城市領先指數.shift(1)
centa_df["cum_percentage"] = centa_df.percentage.cumprod()

# %%
fig = plt.figure(figsize = (10,10))
plt.plot(centa_df.Date, centa_df.cum_percentage)

plt.grid(True)
plt.title("If you invest $1 in Hong Kong Property market in 2010")
plt.xlabel("Year")
plt.ylabel("Index")
# Out:
# Text(0, 0.5, 'Index')
